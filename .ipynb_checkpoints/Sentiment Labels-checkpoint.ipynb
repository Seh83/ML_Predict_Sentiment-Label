# %%
import pandas as pd
import numpy as np

# %%
pd.read_fwf("./data/amazon_cells_labelled.txt")
# Out:
#     So there is no way for me to plug it in here in the US unless I go by a converter.\t0
# 0                       Good case, Excellent value.\t1
# 1                            Great for the jawbone.\t1
# 2    Tied to charger for conversations lasting more...
# 3                                 The mic is great.\t1
# 4    I have to jiggle the plug to get it to line up...
# 5    If you have several dozen or several hundred c...
# 6       If you are Razr owner...you must have this!\t1
# 7               Needless to say, I wasted my money.\t0
# 8                  What a waste of money and time!.\t0
# 9                   And the sound quality is great.\t1
# 10   He was very impressed when going from the orig...
# 11   If the two were seperated by a mere 5+ ft I st...
# 12                         Very good quality though\t1
# 13   The design is very odd, as the ear "clip" is n...
# 14   Highly recommend for any one who has a blue to...
# ...
